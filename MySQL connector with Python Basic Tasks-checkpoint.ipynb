# %%
# !pip install mysql-connector-python

# %%
import mysql.connector as conn
mydb=conn.connect(host='localhost', user='root', passwd='root')

# %%
cursor=mydb.cursor()

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('cardataset',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('world',)]

# %%
cursor.execute("create database cardataset")

# %%
cursor.execute("create table cardataset.car ( buying varchar(10), maintenance varchar(10), doors varchar(10), persons varchar(10), lug_boot varchar(10), safety varchar(10), class varchar(20))")

# %%
cursor.execute("use cardataset")

# %%
cursor.execute("show tables")

# %%
cursor.fetchall()
# Out:
# [('car',)]

# %%
file = open("C:/Users/vmuth/Downloads/car.data")

# %%
file.seek(0)
# Out:
# 0

# %%
file.readlines()
# Out:
# ['vhigh,vhigh,2,2,small,low,unacc\n',
#  'vhigh,vhigh,2,2,small,med,unacc\n',
#  'vhigh,vhigh,2,2,small,high,unacc\n',
#  'vhigh,vhigh,2,2,med,low,unacc\n',
#  'vhigh,vhigh,2,2,med,med,unacc\n',
#  'vhigh,vhigh,2,2,med,high,unacc\n',
#  'vhigh,vhigh,2,2,big,low,unacc\n',
#  'vhigh,vhigh,2,2,big,med,unacc\n',
#  'vhigh,vhigh,2,2,big,high,unacc\n',
#  'vhigh,vhigh,2,4,small,low,unacc\n',
#  'vhigh,vhigh,2,4,small,med,unacc\n',
#  'vhigh,vhigh,2,4,small,high,unacc\n',
#  'vhigh,vhigh,2,4,med,low,unacc\n',
#  'vhigh,vhigh,2,4,med,med,unacc\n',
#  'vhigh,vhigh,2,4,med,high,unacc\n',
#  'vhigh,vhigh,2,4,big,low,unacc\n',
#  'vhigh,vhigh,2,4,big,med,unacc\n',
#  'vhigh,vhigh,2,4,big,high,unacc\n',
#  'vhigh,vhigh,2,more,small,low,unacc\n',
#  'vhigh,vhigh,2,more,small,med,unacc\n',
#  'vhigh,vhigh,2,more,small,high,unacc\n',
#  'vhigh,vhigh,2,more,med,low,unacc\n',
#  'vhigh,vhigh,2,more,med,med,unacc\n',
#  'vhigh,vhigh,2,more,med,high,unacc\n',
#  'vhigh,vhigh,2,more,big,low,unacc\n',
# ...

# %%
import csv
with open("C:/Users/vmuth/Downloads/car.data") as f:
    cardata = csv.reader(f, delimiter='\n')
    for i in cardata:
        print(i)
        print(i[0])
        print(type(i[0]))
        print(i[0].split(','))
        print(','.join(i[0].split(',')))
        cursor.execute('insert into cardataset.car (buying, maintenance, doors, persons, lug_boot, safety, class) values (%s,%s,%s,%s,%s,%s,%s)',i[0].split(','))
    mydb.commit;
# Out:
# ['vhigh,vhigh,2,2,small,low,unacc']
# vhigh,vhigh,2,2,small,low,unacc
# <class 'str'>
# ['vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc']
# vhigh,vhigh,2,2,small,low,unacc
# ['vhigh,vhigh,2,2,small,med,unacc']
# vhigh,vhigh,2,2,small,med,unacc
# <class 'str'>
# ['vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc']
# vhigh,vhigh,2,2,small,med,unacc
# ['vhigh,vhigh,2,2,small,high,unacc']
# vhigh,vhigh,2,2,small,high,unacc
# <class 'str'>
# ['vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc']
# vhigh,vhigh,2,2,small,high,unacc
# ['vhigh,vhigh,2,2,med,low,unacc']
# vhigh,vhigh,2,2,med,low,unacc
# <class 'str'>
# ['vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc']
# vhigh,vhigh,2,2,med,low,unacc
# ['vhigh,vhigh,2,2,med,med,unacc']
# vhigh,vhigh,2,2,med,med,unacc
# <class 'str'>
# ['vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc']
# vhigh,vhigh,2,2,med,med,unacc
# ['vhigh,vhigh,2,2,med,high,unacc']
# vhigh,vhigh,2,2,med,high,unacc
# <class 'str'>
# ...

# %%
cursor.execute("select * from cardataset.car")

# %%
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'med', 'unacc'),
# ...

# %%
cursor.execute("select count(*) from cardataset.car")
cursor.fetchall()
# Out:
# [(3457,)]

# %% [markdown]
# try to group all the data with COL1 AND count occurences of each and every record based on col1 value

# %%
cursor.execute("select buying,count(*) from cardataset.car group by buying")
cursor.fetchall()
# Out:
# [('vhigh', 864), ('high', 864), ('med', 864), ('low', 865)]

# %% [markdown]
# Try to filter a record where col 3 value will be 4

# %%
cursor.execute("select * from cardataset.car where doors=4")
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '4', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'big', 'med', 'unacc'),
# ...

# %% [markdown]
# Try to update a col 3 value with 8 whereever you have value equal to 2

# %%
cursor.execute("select * from cardataset.car where doors != '5more'and doors=2 ")
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'med', 'unacc'),
# ...

# %%
cursor.execute("update cardataset.car set doors=8 where doors != '5more'and doors=2")
mydb.commit;
cursor.execute("select * from cardataset.car where doors=8")
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '8', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'big', 'med', 'unacc'),
# ...

# %%
cursor.execute("update cardataset.car set doors=8 where doors=2")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     522                 query = query.encode('utf-8')
# --> 523             self._cmysql.query(query,
#     524                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Truncated incorrect DOUBLE value: '5more'
#
# During handling of the above exception, another exception occurred:
#
# DataError                                 Traceback (most recent call last)
# <ipython-input-45-2ecaddd892b5> in <module>
# ----> 1 cursor.execute("update cardataset.car set doors=8 where doors=2")
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     267
#     268         try:
# ...

# %% [markdown]
# try to delete table

# %%
cursor.execute("show tables")
cursor.fetchall()
# Out:
# [('car',)]

# %%
cursor.execute("select count(*) from car")
cursor.fetchall()
# Out:
# [(3457,)]

# %%
cursor.execute("delete from car")
cursor.execute("select * from car")
cursor.fetchall()
# Out:
# []

# %%
cursor.execute("show tables")
cursor.fetchall()
# Out:
# [('car',)]

# %%
cursor.execute("drop table car")
cursor.execute("select * from car")
cursor.fetchall()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     522                 query = query.encode('utf-8')
# --> 523             self._cmysql.query(query,
#     524                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Table 'cardataset.car' doesn't exist
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-52-fbab6492beb1> in <module>
#       1 cursor.execute("drop table car")
# ----> 2 cursor.execute("select * from car")
#       3 cursor.fetchall()
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     267
#     268         try:
# ...

# %% [markdown]
# Try to delete database

# %%
cursor.execute("show databases")
cursor.fetchall()
# Out:
# [('cardataset',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('world',)]

# %%
cursor.execute("drop database cardataset")
cursor.execute("show databases")
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('world',)]
